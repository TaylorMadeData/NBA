# %% [markdown]
# ### Import Libraries

# %%
import sqlite3
import pandas as pd

# sqlite3 docs
    # https://docs.python.org/3/library/sqlite3.html

# %% [markdown]
# ### Create Database Variable

# %%
# Create DB B
db = 'NBA.db'

# %%
conn = sqlite3.connect('NBA.db')

# %%
c = conn.cursor()

# %% [markdown]
# ### Sample Syntax

# %%
conn = sqlite3.connect(db)
c = conn.cursor()

for row in df():
    insert_sql = f"INSERT INTO table (col1, col2, col3, col4) VALUES ({row[1]},{row[2]},{row[3]},{row[4]})"
    c.execute(insert_sql)

conn.commit()
conn.close()

# %% [markdown]
# ### Teams Table

# %%
teams = pd.read_sql_query('SELECT * FROM teams', conn)
teams
# Out:
#             id               full_name abbreviation       nickname  \
# 0   1610612737           Atlanta Hawks          ATL          Hawks
# 1   1610612738          Boston Celtics          BOS        Celtics
# 2   1610612739     Cleveland Cavaliers          CLE      Cavaliers
# 3   1610612740    New Orleans Pelicans          NOP       Pelicans
# 4   1610612741           Chicago Bulls          CHI          Bulls
# 5   1610612742        Dallas Mavericks          DAL      Mavericks
# 6   1610612743          Denver Nuggets          DEN        Nuggets
# 7   1610612744   Golden State Warriors          GSW       Warriors
# 8   1610612745         Houston Rockets          HOU        Rockets
# 9   1610612746    Los Angeles Clippers          LAC       Clippers
# 10  1610612747      Los Angeles Lakers          LAL         Lakers
# 11  1610612748              Miami Heat          MIA           Heat
# 12  1610612749         Milwaukee Bucks          MIL          Bucks
# ...

# %% [markdown]
# ### Players Table

# %%
players = pd.read_sql_query('SELECT * FROM active_players', conn)
players
# Out:
#      player_id         full_name first_name  last_name is_active
# 0      1630173  Precious Achiuwa   Precious    Achiuwa         1
# 1       203500      Steven Adams     Steven      Adams         1
# 2      1628389       Bam Adebayo        Bam    Adebayo         1
# 3      1630534      Ochai Agbaji      Ochai     Agbaji         1
# 4      1630583      Santi Aldama      Santi     Aldama         1
# ..         ...               ...        ...        ...       ...
# 577     201152    Thaddeus Young   Thaddeus      Young         1
# 578    1629027        Trae Young       Trae      Young         1
# 579    1630209    Omer Yurtseven       Omer  Yurtseven         1
# 580     203469       Cody Zeller       Cody     Zeller         1
# 581    1627826       Ivica Zubac      Ivica      Zubac         1
#
# [582 rows x 5 columns]

# %% [markdown]
# ### Player Info Table

# %%
player_data = pd.read_sql_query('SELECT * FROM active_player_data', conn)
player_data
# Out:
#      PERSON_ID FIRST_NAME  LAST_NAME DISPLAY_FIRST_LAST  \
# 0      1630173   Precious    Achiuwa   Precious Achiuwa
# 1       203500     Steven      Adams       Steven Adams
# 2      1628389        Bam    Adebayo        Bam Adebayo
# 3      1630534      Ochai     Agbaji       Ochai Agbaji
# 4      1630583      Santi     Aldama       Santi Aldama
# ..         ...        ...        ...                ...
# 577     201152   Thaddeus      Young     Thaddeus Young
# 578    1629027       Trae      Young         Trae Young
# 579    1630209       Omer  Yurtseven     Omer Yurtseven
# 580     203469       Cody     Zeller        Cody Zeller
# 581    1627826      Ivica      Zubac        Ivica Zubac
#
#     DISPLAY_LAST_COMMA_FIRST DISPLAY_FI_LAST       PLAYER_SLUG  \
# 0          Achiuwa, Precious      P. Achiuwa  precious-achiuwa
# 1              Adams, Steven        S. Adams      steven-adams
# 2               Adebayo, Bam      B. Adebayo       bam-adebayo
# ...

# %% [markdown]
# ### Game Results Table (total by team)

# %%
game_results = pd.read_sql_query('SELECT * FROM game_results', conn)
game_results
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME   GAME_ID  \
# 0        22022  1610612754               IND         Indiana Pacers  22200378
# 1        22022  1610612752               NYK        New York Knicks  22200377
# 2        22022  1610612755               PHI     Philadelphia 76ers  22200382
# 3        22022  1610612764               WAS     Washington Wizards  22200378
# 4        22022  1610612742               DAL       Dallas Mavericks  22200386
# ..         ...         ...               ...                    ...       ...
# 767      22022  1610612761               TOR        Toronto Raptors  22200008
# 768      22022  1610612744               GSW  Golden State Warriors  22200002
# 769      22022  1610612738               BOS         Boston Celtics  22200001
# 770      22022  1610612747               LAL     Los Angeles Lakers  22200002
# 771      22022  1610612755               PHI     Philadelphia 76ers  22200001
#
# ...

# %% [markdown]
# ### Boxscore Table

# %%
boxscores = pd.read_sql_query('SELECT * FROM boxscores', conn)
boxscores
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION   TEAM_CITY  PLAYER_ID  \
# 0     22200378  1610612764               WAS  Washington    1630166
# 1     22200378  1610612764               WAS  Washington    1628398
# 2     22200378  1610612764               WAS  Washington     204001
# 3     22200378  1610612764               WAS  Washington    1630557
# 4     22200378  1610612764               WAS  Washington    1628420
# ...        ...         ...               ...         ...        ...
# 9912  22200001  1610612738               BOS      Boston    1631120
# 9913  22200001  1610612738               BOS      Boston    1628382
# 9914  22200001  1610612738               BOS      Boston    1629662
# 9915  22200001  1610612738               BOS      Boston    1628436
# 9916  22200001  1610612738               BOS      Boston    1630202
#
#              PLAYER_NAME  NICKNAME START_POSITION                 COMMENT  \
# 0            Deni Avdija      Deni              F
# ...
